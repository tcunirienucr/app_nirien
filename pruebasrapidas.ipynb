# %%
import pandas as pd

df = pd.read_parquet("data/mapa_latest.parquet")

print(df[['__HOJA_ORIGEN__', '__FECHA_ETL__', '__FILAS_ETL__']].head())
# Out:
#   __HOJA_ORIGEN__        __FECHA_ETL__  __FILAS_ETL__
# 0      mayo2026v4  2026-05-21 20:20:22           7866
# 1      mayo2026v4  2026-05-21 20:20:22           7866
# 2      mayo2026v4  2026-05-21 20:20:22           7866
# 3      mayo2026v4  2026-05-21 20:20:22           7866
# 4      mayo2026v4  2026-05-21 20:20:22           7866
